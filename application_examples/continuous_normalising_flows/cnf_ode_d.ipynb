# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import os
import matplotlib.pyplot as plt

import application_examples.helpers.training as training

# %%
from torchdiffeq import odeint

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
def trace_df_dz(f, z):
    """Calculates the trace of the Jacobian df/dz.
    
    Taken from: https://github.com/rtqichen/ffjord/blob/master/lib/layers/odefunc.py#L13
    """
    sum_diag = 0.
    for i in range(z.shape[1]):
        sum_diag += torch.autograd.grad(f[:, i].sum(), z, create_graph=True)[0].contiguous()[:, i].contiguous()

    return sum_diag.contiguous()

# %% [markdown]
# # Simple example of lerning a normal distribution

# %%
args = {
    'niters': 5000,
    'lr': 1e-3,
    'num_samples': 500,
    'hidden_dim': 20,
    'width': 20,
    'results_dir': 'results'
}

# %% [markdown]
# The distribution to be learnt is $\mathcal{N}(0, 5)$.

# %%
def get_batch_normal(num_samples):
    x = torch.distributions.normal.Normal(torch.tensor([0.0]), torch.tensor([5.0])).sample(sample_shape=torch.Size([num_samples])).type(torch.float32)
    logp_diff_t1 = torch.zeros(num_samples, 1).type(torch.float32)
    
    return x, logp_diff_t1

# %% [markdown]
# We'll use a simple neural network with one hidden layer.

# %%
class ODEnn(nn.Module):

    def __init__(self, in_out_dim=1, hidden_dim=20):
        super(ODEnn, self).__init__()

        self.net = nn.Sequential(
            # ODE-Net's neural network architecture: 1 hidden layer with 50 neurons, tanh activation, 2 output neurons
            nn.Linear(in_out_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, in_out_dim),
        )

        # Initialize the weights and biases of the network for better convergence
        for m in self.net.modules():
            if isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, mean=0, std=0.1)
                nn.init.constant_(m.bias, val=0)

    # Define the forward pass of the network
    def forward(self, t, states):
        z = states[0]
        logp_z = states[1]
        
        with torch.set_grad_enabled(True):
            z.requires_grad_(True)
            
            dz_dt = self.net(z)
            dlogp_z_t = -trace_df_dz(dz_dt, z).view(-1,1)
            
        return (dz_dt, dlogp_z_t)

# %% [markdown]
# Define the vector field here. We'll use the ODE-Net architecture with starting time 0 and terminal time 10. The initial distribution is $\mathcal{N}(0, 1)$.

# %%
t0 = 0
t1 = 10
func = ODEnn(in_out_dim=1, hidden_dim=50).to(device)
optimizer = optim.Adam(func.parameters(), lr=args['lr'])

p_z0 = torch.distributions.normal.Normal(torch.tensor([0.0]), torch.tensor([1.0]))

# %% [markdown]
# Let's train the network.

# %%
loss_meter = training.RunningAverageMeter(0.97)
print("Number of parameters: {}".format(sum(p.numel() for p in func.parameters())))

for itr in range(1, args['niters']+1):
    optimizer.zero_grad()
    
    x, logp_diff_t1 = get_batch_normal(args['num_samples'])
    
    z_t, logp_diff_t = odeint(
        func,
        (x, logp_diff_t1),
        torch.tensor([t1, t0]).type(torch.float32).to(device),
        atol=1e-5,
        rtol=1e-5,
        method='dopri5'
    )
    
    z_t0, logp_diff_t0 = z_t[-1], logp_diff_t[-1]
    
    logp_x = p_z0.log_prob(z_t0) - logp_diff_t0
    
    loss = -logp_x.mean(0)
    
    loss.backward()
    optimizer.step()
    
    loss_meter.update(loss.item())
    
    if itr % 100 == 0:
        print('Iter: {}, running avg loss: {:.4f}'.format(itr, loss_meter.avg))
# Out:
# Number of parameters: 151
# Iter: 100, running avg loss: 3.0291
# Iter: 200, running avg loss: 3.0251
# Iter: 300, running avg loss: 3.0358
# Iter: 400, running avg loss: 3.0229
# Iter: 500, running avg loss: 3.0319
# Iter: 600, running avg loss: 3.0319
# Iter: 700, running avg loss: 3.0311
# Iter: 800, running avg loss: 3.0321
# Iter: 900, running avg loss: 3.0305
# Iter: 1000, running avg loss: 3.0288
# Iter: 1100, running avg loss: 3.0303
# Iter: 1200, running avg loss: 3.0344
# Iter: 1300, running avg loss: 3.0305
# Iter: 1400, running avg loss: 3.0272
# Iter: 1500, running avg loss: 3.0321
# Iter: 1600, running avg loss: 3.0298
# Iter: 1700, running avg loss: 3.0336
# Iter: 1800, running avg loss: 3.0308
# Iter: 1900, running avg loss: 3.0205
# Iter: 2000, running avg loss: 3.0256
# Iter: 2100, running avg loss: 3.0308
# Iter: 2200, running avg loss: 3.0326
# Iter: 2300, running avg loss: 3.0293
# Iter: 2400, running avg loss: 3.0262
# Iter: 2500, running avg loss: 3.0327
# Iter: 2600, running avg loss: 3.0272
# Iter: 2700, running avg loss: 3.0309
# Iter: 2800, running avg loss: 3.0310
# Iter: 2900, running avg loss: 3.0261
# Iter: 3000, running avg loss: 3.0265
# Iter: 3100, running avg loss: 3.0308
# Iter: 3200, running avg loss: 3.0238
# Iter: 3300, running avg loss: 3.0279
# Iter: 3400, running avg loss: 3.0299
# Iter: 3500, running avg loss: 3.0292
# Iter: 3600, running avg loss: 3.0263
# Iter: 3700, running avg loss: 3.0295
# Iter: 3800, running avg loss: 3.0306
# Iter: 3900, running avg loss: 3.0356
# Iter: 4000, running avg loss: 3.0314
# Iter: 4100, running avg loss: 3.0261
# Iter: 4200, running avg loss: 3.0376
# Iter: 4300, running avg loss: 3.0350
# Iter: 4400, running avg loss: 3.0286
# Iter: 4500, running avg loss: 3.0283
# Iter: 4600, running avg loss: 3.0306
# Iter: 4700, running avg loss: 3.0310
# Iter: 4800, running avg loss: 3.0310
# Iter: 4900, running avg loss: 3.0268
# Iter: 5000, running avg loss: 3.0272

# %%
loss_meter.plot_history()

# %%
# Get points from the original distribution
y_0 = torch.distributions.normal.Normal(torch.tensor([0.0]), torch.tensor([1.0])).sample(sample_shape=torch.Size([100000])).type(torch.float32)
# Get their log probability
logp_t0 = torch.distributions.normal.Normal(torch.tensor([0.0]), torch.tensor([1.0])).log_prob(y_0).type(torch.float32)

# Transform the points
y_t_empirical, _ = odeint(
        func, 
        (y_0, logp_t0), 
        torch.tensor([t0, t1]).type(torch.float32), 
        method='dopri5', 
        atol=1e-5, 
        rtol=1e-5)

# Plot the objective distribution
x = np.linspace(-20, 20, 1000)
x_tensor = torch.tensor(x).type(torch.float32)
obj = torch.distributions.normal.Normal(torch.tensor([0.0]), torch.tensor([5.0])).log_prob(x_tensor).type(torch.float32)

# Plot the learnt distribution
x_tensor = torch.tensor(np.linspace(-15,15,1000)).type(torch.float32)
origin_d = torch.distributions.normal.Normal(torch.tensor([0.0]), torch.tensor([1.0])).log_prob(x_tensor).type(torch.float32)

x_t, logp_x_t = odeint(
        func, 
        (x_tensor.view(-1,1), origin_d.view(-1,1)), 
        torch.tensor([t0, t1]).type(torch.float32), 
        method='dopri5', 
        atol=1e-5, 
        rtol=1e-5
    )
x_t, logp_x_t = x_t[-1].detach().cpu().numpy(), logp_x_t[-1].exp().detach().cpu().numpy()

#plt.hist(, bins=100, density=True, label='Original histogram')
plt.plot(x, obj.exp(), label='Objective distribution')
#plt.hist(get_batch_normal(100000)[0].view(100000), bins=100, density=True, label='Samples')
plt.hist(y_t_empirical[-1].detach().cpu().numpy(), bins=100, density=True, label='Learnt histogram')
plt.plot(x_t, logp_x_t, '-.', label='Learnt distribution')
plt.title('Transformed distribution')
plt.xlim(-20,20)
plt.legend()
plt.show()

# %% [markdown]
# Now let's see how the distribution changes over time.

# %%
from IPython.display import display, HTML
from PIL import Image
x_0 = torch.distributions.normal.Normal(torch.tensor([0.0]), torch.tensor([1.0])).sample(sample_shape=torch.Size([100000])).type(torch.float32)

logp_t0 = torch.distributions.normal.Normal(torch.tensor([0.0]), torch.tensor([1.0])).log_prob(y_0).type(torch.float32)

times = np.linspace(t0, t1, 10)

x_t, _ = odeint(
        func, 
        (x_0, logp_t0), 
        torch.tensor(times).type(torch.float32), 
        method='dopri5', 
        atol=1e-5, 
        rtol=1e-5
    )

x_t = x_t.detach().cpu().numpy()

if not os.path.exists('cnf_one_images'):
    os.makedirs('cnf_one_images')

# Define the function to generate the plot
def plot_and_save(i):
    fig, ax = plt.subplots(1, 1, figsize=(5, 5))
    plt.suptitle('Transformed distribution at time t={:.2f}'.format(times[i]))
    plt.tight_layout()
    
    
    ax.plot(x, obj.exp(), label='Objective distribution')
    ax.hist(x_t[i], bins=100, density=True)
    plt.xlim(-20,20)
    plt.ylim(0,0.5)

    # Save the plot as an image
    plt.savefig(os.path.join('cnf_one_images','frame{}.png'.format(i)))
    plt.close()


# Generate the GIF
for i in range(10):
    plot_and_save(i)

# Create the GIF using imageio
gif_images = [os.path.join('cnf_one_images','frame{}.png'.format(i)) for i in range(10)]

img, *imgs = [Image.open(img) for img in gif_images]
gif_path = os.path.join('cnf_one_images','result.gif')
img.save(fp=gif_path, format='GIF', append_images=imgs,
         save_all=True, duration=500, loop=0)
display(HTML(f'<img src="{gif_path}">'))
img.close()
for im in imgs:
    im.close()
# Out:
# <img src="cnf_one_images/result.gif">

# %% [markdown]
# # A "harder" example to learn a two modal distribution

# %%
args = {
    'niters': 10000,
    'lr': 1e-3,
    'num_samples': 1000,
    'hidden_dim': 20,
    'width': 20,
    'results_dir': 'results'
}

# %%
class HyperNetwork(nn.Module):
    """Hyper-network allowing f(z(t), t) to change with time.

    Taken from: https://github.com/rtqichen/torchdiffeq/blob/master/examples/cnf.py
    """

    def __init__(self, in_out_dim, hidden_dim, width):
        super().__init__()

        blocksize = width * in_out_dim

        self.fc1 = nn.Linear(1, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, 3 * blocksize + width)

        self.in_out_dim = in_out_dim
        self.hidden_dim = hidden_dim
        self.width = width
        self.blocksize = blocksize

    def forward(self, t):
        # predict params
        params = t.reshape(1, 1)
        params = torch.tanh(self.fc1(params))
        params = torch.tanh(self.fc2(params))
        params = self.fc3(params)

        # restructure
        params = params.reshape(-1)
        W = params[:self.blocksize].reshape(self.width, self.in_out_dim, 1)

        U = params[self.blocksize:2 * self.blocksize].reshape(self.width, 1, self.in_out_dim)

        G = params[2 * self.blocksize:3 * self.blocksize].reshape(self.width, 1, self.in_out_dim)
        U = U * torch.sigmoid(G)

        B = params[3 * self.blocksize:].reshape(self.width, 1, 1)
        return [W, B, U]

# %%
# Continuous normalising flow
class CNF(nn.Module):
    """Continuous normalising flow model.
    
    Taken from: https://github.com/rtqichen/torchdiffeq/blob/master/examples/cnf.py
    """

    def __init__(self, in_out_dim, hidden_dim, width):
        super().__init__()
        self.in_out_dim = in_out_dim
        self.hidden_dim = hidden_dim
        self.width = width
        self.hyper_net = HyperNetwork(in_out_dim, hidden_dim, width)

    def forward(self, t, states):
        z = states[0]
        logp_z = states[1]

        batchsize = z.shape[0]

        with torch.set_grad_enabled(True):
            z.requires_grad_(True)

            W, B, U = self.hyper_net(t) # Parameters from the hypernetwork
            Z = torch.unsqueeze(z, 0).repeat(self.width, 1, 1)
            h = torch.tanh(torch.matmul(Z, W) + B)
            dz_dt = torch.matmul(h, U).mean(0)  # Basically, f_{theta}(t, z(t))

            dlogp_z_dt = -trace_df_dz(dz_dt, z).view(batchsize, 1)  # -tr(df/dz) -> Instantaneous change of variables theorem

        return (dz_dt, dlogp_z_dt)

# %% [markdown]
# ## Objective distribution
# We'll try to learn a bimodal distribution generated by two beta processes. The Beta distribution has pdf:
# $$
# f(x; \alpha, \beta) = \frac{x^{\alpha-1}(1-x)^{\beta-1}}{B(\alpha, \beta)}
# $$
# where $B(\alpha, \beta)$ is the beta function. The beta function is defined as:
# $$
# B(\alpha, \beta) = \int_0^1 t^{\alpha-1}(1-t)^{\beta-1} dt
# $$
# The first process has parameters $\alpha=2, \beta=5$ and the second process has parameters $\alpha=5, \beta=2$. Both processes will be mixed with equal probability.

# %%
def get_batch(num_samples):
    alpha = 2
    beta = 5
    x1 = torch.distributions.beta.Beta(alpha, beta).sample(sample_shape=torch.Size([num_samples // 2, 1])).type(
        torch.float32)

    alpha = 5
    beta = 2
    x2 = torch.distributions.beta.Beta(alpha, beta).sample(
        sample_shape=torch.Size([num_samples - num_samples // 2, 1])).type(torch.float32)

    # Sample from the chosen process
    x = torch.cat([x1, x2])
    # Shuffle the samples
    x = x[torch.randperm(num_samples)]
    logp_diff_t1 = torch.zeros(num_samples, 1).type(torch.float32)

    return x, logp_diff_t1

# %%
from scipy.stats import beta
import matplotlib.pyplot as plt

# Plot the objective distribution
y_points, _ = get_batch(50000)
x = np.linspace(0, 1, 1000)
y = 0.5 * beta.pdf(x, 2, 5) + 0.5 * beta.pdf(x, 5, 2)

plt.plot(x, y, label='Objective distribution')
plt.hist(y_points.view(50000), bins=100, density=True, label='Samples')
plt.title('Objective distribution')
plt.legend()
plt.show()

# %%
t0 = 0
t1 = 10
func = CNF(in_out_dim=1, hidden_dim=args['hidden_dim'], width=args['width']).to(device)
optimizer = optim.Adam(func.parameters(), lr=args['lr'])

p_z0 = torch.distributions.normal.Normal(torch.tensor([0.0]), torch.tensor([1.0]))

# %%
loss_meter = training.RunningAverageMeter()
print("Number of parameters: {}".format(sum(p.numel() for p in func.parameters())))

for itr in range(1, args['niters'] + 1):
    optimizer.zero_grad()
    
    x, logp_diff_t1 = get_batch(args['num_samples'])
    
    z_t, logp_z_t = odeint(
        func, 
        (x, logp_diff_t1), 
        torch.tensor([t1, t0]).type(torch.float32), 
        method='dopri5', 
        atol=1e-5, 
        rtol=1e-5)
    
    z_t0, logp_diff_t0 = z_t[-1], logp_z_t[-1]
    
    logp_x = p_z0.log_prob(z_t0).to(device) - logp_diff_t0.view(-1)
    
    loss = -torch.mean(logp_x)
    
    loss.backward()
    optimizer.step()
    
    loss_meter.update(loss.item())
    
    if itr % 10 == 0:
        print('Iter: {}, running avg loss: {:.4f}'.format(itr, loss_meter.avg))
# Out:
# Number of parameters: 2140
# Iter: 10, running avg loss: 1.2017
# Iter: 20, running avg loss: 1.1622
# Iter: 30, running avg loss: 1.0907
# Iter: 40, running avg loss: 1.0063
# Iter: 50, running avg loss: 0.9281
# Iter: 60, running avg loss: 0.8562
# Iter: 70, running avg loss: 0.7884
# Iter: 80, running avg loss: 0.7266
# Iter: 90, running avg loss: 0.6705
# Iter: 100, running avg loss: 0.6188
# Iter: 110, running avg loss: 0.5711
# Iter: 120, running avg loss: 0.5267
# Iter: 130, running avg loss: 0.4859
# Iter: 140, running avg loss: 0.4482
# Iter: 150, running avg loss: 0.4142
# Iter: 160, running avg loss: 0.3819
# Iter: 170, running avg loss: 0.3516
# Iter: 180, running avg loss: 0.3224
# Iter: 190, running avg loss: 0.2941
# Iter: 200, running avg loss: 0.2665
# Iter: 210, running avg loss: 0.2411
# Iter: 220, running avg loss: 0.2171
# Iter: 230, running avg loss: 0.1943
# Iter: 240, running avg loss: 0.1735
# Iter: 250, running avg loss: 0.1540
# Iter: 260, running avg loss: 0.1371
# Iter: 270, running avg loss: 0.1215
# Iter: 280, running avg loss: 0.1069
# Iter: 290, running avg loss: 0.0941
# Iter: 300, running avg loss: 0.0823
# Iter: 310, running avg loss: 0.0713
# Iter: 320, running avg loss: 0.0613
# Iter: 330, running avg loss: 0.0524
# Iter: 340, running avg loss: 0.0447
# Iter: 350, running avg loss: 0.0379
# Iter: 360, running avg loss: 0.0318
# Iter: 370, running avg loss: 0.0264
# Iter: 380, running avg loss: 0.0211
# Iter: 390, running avg loss: 0.0164
# Iter: 400, running avg loss: 0.0115
# Iter: 410, running avg loss: 0.0075
# Iter: 420, running avg loss: 0.0035
# Iter: 430, running avg loss: 0.0001
# Iter: 440, running avg loss: -0.0036
# Iter: 450, running avg loss: -0.0064
# Iter: 460, running avg loss: -0.0087
# Iter: 470, running avg loss: -0.0105
# Iter: 480, running avg loss: -0.0128
# Iter: 490, running avg loss: -0.0147
# Iter: 500, running avg loss: -0.0163
# Iter: 510, running avg loss: -0.0175
# Iter: 520, running avg loss: -0.0184
# Iter: 530, running avg loss: -0.0197
# Iter: 540, running avg loss: -0.0211
# Iter: 550, running avg loss: -0.0228
# Iter: 560, running avg loss: -0.0240
# Iter: 570, running avg loss: -0.0247
# Iter: 580, running avg loss: -0.0256
# Iter: 590, running avg loss: -0.0255
# Iter: 600, running avg loss: -0.0261
# Iter: 610, running avg loss: -0.0269
# Iter: 620, running avg loss: -0.0277
# Iter: 630, running avg loss: -0.0285
# Iter: 640, running avg loss: -0.0295
# Iter: 650, running avg loss: -0.0304
# Iter: 660, running avg loss: -0.0310
# Iter: 670, running avg loss: -0.0313
# Iter: 680, running avg loss: -0.0313
# Iter: 690, running avg loss: -0.0316
# Iter: 700, running avg loss: -0.0321
# Iter: 710, running avg loss: -0.0326
# Iter: 720, running avg loss: -0.0327
# Iter: 730, running avg loss: -0.0335
# Iter: 740, running avg loss: -0.0346
# Iter: 750, running avg loss: -0.0350
# Iter: 760, running avg loss: -0.0349
# Iter: 770, running avg loss: -0.0353
# Iter: 780, running avg loss: -0.0359
# Iter: 790, running avg loss: -0.0363
# Iter: 800, running avg loss: -0.0368
# Iter: 810, running avg loss: -0.0371
# Iter: 820, running avg loss: -0.0372
# Iter: 830, running avg loss: -0.0374
# Iter: 840, running avg loss: -0.0370
# Iter: 850, running avg loss: -0.0367
# Iter: 860, running avg loss: -0.0365
# Iter: 870, running avg loss: -0.0367
# Iter: 880, running avg loss: -0.0368
# Iter: 890, running avg loss: -0.0372
# Iter: 900, running avg loss: -0.0373
# Iter: 910, running avg loss: -0.0372
# Iter: 920, running avg loss: -0.0372
# Iter: 930, running avg loss: -0.0369
# Iter: 940, running avg loss: -0.0367
# Iter: 950, running avg loss: -0.0362
# Iter: 960, running avg loss: -0.0357
# Iter: 970, running avg loss: -0.0353
# Iter: 980, running avg loss: -0.0350
# Iter: 990, running avg loss: -0.0350
# Iter: 1000, running avg loss: -0.0352
# Iter: 1010, running avg loss: -0.0355
# Iter: 1020, running avg loss: -0.0353
# Iter: 1030, running avg loss: -0.0356
# Iter: 1040, running avg loss: -0.0361
# Iter: 1050, running avg loss: -0.0366
# Iter: 1060, running avg loss: -0.0364
# Iter: 1070, running avg loss: -0.0367
# Iter: 1080, running avg loss: -0.0367
# Iter: 1090, running avg loss: -0.0367
# Iter: 1100, running avg loss: -0.0367
# Iter: 1110, running avg loss: -0.0368
# Iter: 1120, running avg loss: -0.0370
# Iter: 1130, running avg loss: -0.0371
# Iter: 1140, running avg loss: -0.0378
# Iter: 1150, running avg loss: -0.0382
# Iter: 1160, running avg loss: -0.0385
# Iter: 1170, running avg loss: -0.0387
# Iter: 1180, running avg loss: -0.0390
# Iter: 1190, running avg loss: -0.0396
# Iter: 1200, running avg loss: -0.0394
# Iter: 1210, running avg loss: -0.0392
# Iter: 1220, running avg loss: -0.0394
# Iter: 1230, running avg loss: -0.0394
# Iter: 1240, running avg loss: -0.0394
# Iter: 1250, running avg loss: -0.0394
# Iter: 1260, running avg loss: -0.0394
# Iter: 1270, running avg loss: -0.0394
# Iter: 1280, running avg loss: -0.0393
# Iter: 1290, running avg loss: -0.0393
# Iter: 1300, running avg loss: -0.0395
# Iter: 1310, running avg loss: -0.0391
# Iter: 1320, running avg loss: -0.0392
# Iter: 1330, running avg loss: -0.0395
# Iter: 1340, running avg loss: -0.0399
# Iter: 1350, running avg loss: -0.0401
# Iter: 1360, running avg loss: -0.0403
# Iter: 1370, running avg loss: -0.0405
# Iter: 1380, running avg loss: -0.0406
# Iter: 1390, running avg loss: -0.0404
# Iter: 1400, running avg loss: -0.0401
# Iter: 1410, running avg loss: -0.0403
# Iter: 1420, running avg loss: -0.0406
# Iter: 1430, running avg loss: -0.0409
# Iter: 1440, running avg loss: -0.0411
# Iter: 1450, running avg loss: -0.0412
# Iter: 1460, running avg loss: -0.0408
# Iter: 1470, running avg loss: -0.0406
# Iter: 1480, running avg loss: -0.0408
# Iter: 1490, running avg loss: -0.0406
# Iter: 1500, running avg loss: -0.0403
# Iter: 1510, running avg loss: -0.0399
# Iter: 1520, running avg loss: -0.0398
# Iter: 1530, running avg loss: -0.0395
# Iter: 1540, running avg loss: -0.0396
# Iter: 1550, running avg loss: -0.0397
# Iter: 1560, running avg loss: -0.0395
# Iter: 1570, running avg loss: -0.0395
# Iter: 1580, running avg loss: -0.0392
# Iter: 1590, running avg loss: -0.0394
# Iter: 1600, running avg loss: -0.0397
# Iter: 1610, running avg loss: -0.0399
# Iter: 1620, running avg loss: -0.0400
# Iter: 1630, running avg loss: -0.0400
# Iter: 1640, running avg loss: -0.0399
# Iter: 1650, running avg loss: -0.0397
# Iter: 1660, running avg loss: -0.0399
# Iter: 1670, running avg loss: -0.0399
# Iter: 1680, running avg loss: -0.0397
# Iter: 1690, running avg loss: -0.0391
# Iter: 1700, running avg loss: -0.0392
# Iter: 1710, running avg loss: -0.0390
# Iter: 1720, running avg loss: -0.0389
# Iter: 1730, running avg loss: -0.0387
# Iter: 1740, running avg loss: -0.0389
# Iter: 1750, running avg loss: -0.0389
# Iter: 1760, running avg loss: -0.0391
# Iter: 1770, running avg loss: -0.0394
# Iter: 1780, running avg loss: -0.0393
# Iter: 1790, running avg loss: -0.0396
# Iter: 1800, running avg loss: -0.0400
# Iter: 1810, running avg loss: -0.0404
# Iter: 1820, running avg loss: -0.0406
# Iter: 1830, running avg loss: -0.0406
# Iter: 1840, running avg loss: -0.0410
# Iter: 1850, running avg loss: -0.0410
# Iter: 1860, running avg loss: -0.0410
# Iter: 1870, running avg loss: -0.0414
# Iter: 1880, running avg loss: -0.0416
# Iter: 1890, running avg loss: -0.0415
# Iter: 1900, running avg loss: -0.0413
# Iter: 1910, running avg loss: -0.0410
# Iter: 1920, running avg loss: -0.0410
# Iter: 1930, running avg loss: -0.0404
# Iter: 1940, running avg loss: -0.0409
# Iter: 1950, running avg loss: -0.0413
# Iter: 1960, running avg loss: -0.0415
# Iter: 1970, running avg loss: -0.0413
# Iter: 1980, running avg loss: -0.0411
# Iter: 1990, running avg loss: -0.0409
# Iter: 2000, running avg loss: -0.0412
# Iter: 2010, running avg loss: -0.0412
# Iter: 2020, running avg loss: -0.0412
# Iter: 2030, running avg loss: -0.0414
# Iter: 2040, running avg loss: -0.0409
# Iter: 2050, running avg loss: -0.0400
# Iter: 2060, running avg loss: -0.0399
# Iter: 2070, running avg loss: -0.0402
# Iter: 2080, running avg loss: -0.0405
# Iter: 2090, running avg loss: -0.0401
# Iter: 2100, running avg loss: -0.0405
# Iter: 2110, running avg loss: -0.0406
# Iter: 2120, running avg loss: -0.0406
# Iter: 2130, running avg loss: -0.0409
# Iter: 2140, running avg loss: -0.0407
# Iter: 2150, running avg loss: -0.0411
# Iter: 2160, running avg loss: -0.0410
# Iter: 2170, running avg loss: -0.0408
# Iter: 2180, running avg loss: -0.0416
# Iter: 2190, running avg loss: -0.0419
# Iter: 2200, running avg loss: -0.0421
# Iter: 2210, running avg loss: -0.0417
# Iter: 2220, running avg loss: -0.0417
# Iter: 2230, running avg loss: -0.0418
# Iter: 2240, running avg loss: -0.0422
# Iter: 2250, running avg loss: -0.0420
# Iter: 2260, running avg loss: -0.0420
# Iter: 2270, running avg loss: -0.0423
# Iter: 2280, running avg loss: -0.0425
# Iter: 2290, running avg loss: -0.0423
# Iter: 2300, running avg loss: -0.0420
# Iter: 2310, running avg loss: -0.0413
# Iter: 2320, running avg loss: -0.0407
# Iter: 2330, running avg loss: -0.0406
# Iter: 2340, running avg loss: -0.0405
# Iter: 2350, running avg loss: -0.0405
# Iter: 2360, running avg loss: -0.0402
# Iter: 2370, running avg loss: -0.0406
# Iter: 2380, running avg loss: -0.0403
# Iter: 2390, running avg loss: -0.0403
# Iter: 2400, running avg loss: -0.0406
# Iter: 2410, running avg loss: -0.0411
# Iter: 2420, running avg loss: -0.0409
# Iter: 2430, running avg loss: -0.0411
# Iter: 2440, running avg loss: -0.0416
# Iter: 2450, running avg loss: -0.0417
# Iter: 2460, running avg loss: -0.0425
# Iter: 2470, running avg loss: -0.0421
# Iter: 2480, running avg loss: -0.0424
# Iter: 2490, running avg loss: -0.0424
# Iter: 2500, running avg loss: -0.0426
# Iter: 2510, running avg loss: -0.0430
# Iter: 2520, running avg loss: -0.0430
# Iter: 2530, running avg loss: -0.0431
# Iter: 2540, running avg loss: -0.0431
# Iter: 2550, running avg loss: -0.0430
# Iter: 2560, running avg loss: -0.0423
# Iter: 2570, running avg loss: -0.0418
# Iter: 2580, running avg loss: -0.0417
# Iter: 2590, running avg loss: -0.0414
# Iter: 2600, running avg loss: -0.0415
# Iter: 2610, running avg loss: -0.0418
# Iter: 2620, running avg loss: -0.0421
# Iter: 2630, running avg loss: -0.0424
# Iter: 2640, running avg loss: -0.0426
# Iter: 2650, running avg loss: -0.0423
# Iter: 2660, running avg loss: -0.0421
# Iter: 2670, running avg loss: -0.0423
# Iter: 2680, running avg loss: -0.0425
# Iter: 2690, running avg loss: -0.0425
# Iter: 2700, running avg loss: -0.0430
# Iter: 2710, running avg loss: -0.0431
# Iter: 2720, running avg loss: -0.0429
# Iter: 2730, running avg loss: -0.0431
# Iter: 2740, running avg loss: -0.0432
# Iter: 2750, running avg loss: -0.0429
# Iter: 2760, running avg loss: -0.0429
# Iter: 2770, running avg loss: -0.0426
# Iter: 2780, running avg loss: -0.0424
# Iter: 2790, running avg loss: -0.0423
# Iter: 2800, running avg loss: -0.0423
# Iter: 2810, running avg loss: -0.0422
# Iter: 2820, running avg loss: -0.0424
# Iter: 2830, running avg loss: -0.0425
# Iter: 2840, running avg loss: -0.0422
# Iter: 2850, running avg loss: -0.0420
# Iter: 2860, running avg loss: -0.0418
# Iter: 2870, running avg loss: -0.0422
# Iter: 2880, running avg loss: -0.0424
# Iter: 2890, running avg loss: -0.0430
# Iter: 2900, running avg loss: -0.0430
# Iter: 2910, running avg loss: -0.0430
# Iter: 2920, running avg loss: -0.0426
# Iter: 2930, running avg loss: -0.0426
# Iter: 2940, running avg loss: -0.0427
# Iter: 2950, running avg loss: -0.0427
# Iter: 2960, running avg loss: -0.0430
# Iter: 2970, running avg loss: -0.0429
# Iter: 2980, running avg loss: -0.0428
# Iter: 2990, running avg loss: -0.0430
# Iter: 3000, running avg loss: -0.0432
# Iter: 3010, running avg loss: -0.0430
# Iter: 3020, running avg loss: -0.0427
# Iter: 3030, running avg loss: -0.0430
# Iter: 3040, running avg loss: -0.0428
# Iter: 3050, running avg loss: -0.0429
# Iter: 3060, running avg loss: -0.0431
# Iter: 3070, running avg loss: -0.0434
# Iter: 3080, running avg loss: -0.0435
# Iter: 3090, running avg loss: -0.0440
# Iter: 3100, running avg loss: -0.0437
# Iter: 3110, running avg loss: -0.0436
# Iter: 3120, running avg loss: -0.0435
# Iter: 3130, running avg loss: -0.0436
# Iter: 3140, running avg loss: -0.0436
# Iter: 3150, running avg loss: -0.0437
# Iter: 3160, running avg loss: -0.0438
# Iter: 3170, running avg loss: -0.0436
# Iter: 3180, running avg loss: -0.0432
# Iter: 3190, running avg loss: -0.0437
# Iter: 3200, running avg loss: -0.0437
# Iter: 3210, running avg loss: -0.0431
# Iter: 3220, running avg loss: -0.0429
# Iter: 3230, running avg loss: -0.0429
# Iter: 3240, running avg loss: -0.0427
# Iter: 3250, running avg loss: -0.0430
# Iter: 3260, running avg loss: -0.0433
# Iter: 3270, running avg loss: -0.0431
# Iter: 3280, running avg loss: -0.0430
# Iter: 3290, running avg loss: -0.0430
# Iter: 3300, running avg loss: -0.0429
# Iter: 3310, running avg loss: -0.0426
# Iter: 3320, running avg loss: -0.0430
# Iter: 3330, running avg loss: -0.0427
# Iter: 3340, running avg loss: -0.0430
# Iter: 3350, running avg loss: -0.0430
# Iter: 3360, running avg loss: -0.0424
# Iter: 3370, running avg loss: -0.0423
# Iter: 3380, running avg loss: -0.0424
# Iter: 3390, running avg loss: -0.0424
# Iter: 3400, running avg loss: -0.0427
# Iter: 3410, running avg loss: -0.0426
# Iter: 3420, running avg loss: -0.0427
# Iter: 3430, running avg loss: -0.0426
# Iter: 3440, running avg loss: -0.0424
# Iter: 3450, running avg loss: -0.0428
# Iter: 3460, running avg loss: -0.0429
# Iter: 3470, running avg loss: -0.0428
# Iter: 3480, running avg loss: -0.0431
# Iter: 3490, running avg loss: -0.0427
# Iter: 3500, running avg loss: -0.0428
# Iter: 3510, running avg loss: -0.0428
# Iter: 3520, running avg loss: -0.0435
# Iter: 3530, running avg loss: -0.0439
# Iter: 3540, running avg loss: -0.0438
# Iter: 3550, running avg loss: -0.0439
# Iter: 3560, running avg loss: -0.0436
# Iter: 3570, running avg loss: -0.0432
# Iter: 3580, running avg loss: -0.0435
# Iter: 3590, running avg loss: -0.0434
# Iter: 3600, running avg loss: -0.0433
# Iter: 3610, running avg loss: -0.0435
# Iter: 3620, running avg loss: -0.0438
# Iter: 3630, running avg loss: -0.0443
# Iter: 3640, running avg loss: -0.0445
# Iter: 3650, running avg loss: -0.0445
# Iter: 3660, running avg loss: -0.0446
# Iter: 3670, running avg loss: -0.0442
# Iter: 3680, running avg loss: -0.0440
# Iter: 3690, running avg loss: -0.0439
# Iter: 3700, running avg loss: -0.0435
# Iter: 3710, running avg loss: -0.0436
# Iter: 3720, running avg loss: -0.0439
# Iter: 3730, running avg loss: -0.0438
# Iter: 3740, running avg loss: -0.0434
# Iter: 3750, running avg loss: -0.0436
# Iter: 3760, running avg loss: -0.0437
# Iter: 3770, running avg loss: -0.0433
# Iter: 3780, running avg loss: -0.0432
# Iter: 3790, running avg loss: -0.0429
# Iter: 3800, running avg loss: -0.0429
# Iter: 3810, running avg loss: -0.0426
# Iter: 3820, running avg loss: -0.0426
# Iter: 3830, running avg loss: -0.0431
# Iter: 3840, running avg loss: -0.0430
# Iter: 3850, running avg loss: -0.0433
# Iter: 3860, running avg loss: -0.0436
# Iter: 3870, running avg loss: -0.0429
# Iter: 3880, running avg loss: -0.0430
# Iter: 3890, running avg loss: -0.0429
# Iter: 3900, running avg loss: -0.0429
# Iter: 3910, running avg loss: -0.0429
# Iter: 3920, running avg loss: -0.0431
# Iter: 3930, running avg loss: -0.0433
# Iter: 3940, running avg loss: -0.0435
# Iter: 3950, running avg loss: -0.0437
# Iter: 3960, running avg loss: -0.0442
# Iter: 3970, running avg loss: -0.0441
# Iter: 3980, running avg loss: -0.0443
# Iter: 3990, running avg loss: -0.0441
# Iter: 4000, running avg loss: -0.0442
# Iter: 4010, running avg loss: -0.0443
# Iter: 4020, running avg loss: -0.0443
# Iter: 4030, running avg loss: -0.0441
# Iter: 4040, running avg loss: -0.0443
# Iter: 4050, running avg loss: -0.0440
# Iter: 4060, running avg loss: -0.0436
# Iter: 4070, running avg loss: -0.0434
# Iter: 4080, running avg loss: -0.0436
# Iter: 4090, running avg loss: -0.0441
# Iter: 4100, running avg loss: -0.0444
# Iter: 4110, running avg loss: -0.0444
# Iter: 4120, running avg loss: -0.0441
# Iter: 4130, running avg loss: -0.0440
# Iter: 4140, running avg loss: -0.0444
# Iter: 4150, running avg loss: -0.0445
# Iter: 4160, running avg loss: -0.0446
# Iter: 4170, running avg loss: -0.0445
# Iter: 4180, running avg loss: -0.0446
# Iter: 4190, running avg loss: -0.0445
# Iter: 4200, running avg loss: -0.0441
# Iter: 4210, running avg loss: -0.0442
# Iter: 4220, running avg loss: -0.0443
# Iter: 4230, running avg loss: -0.0441
# Iter: 4240, running avg loss: -0.0444
# Iter: 4250, running avg loss: -0.0439
# Iter: 4260, running avg loss: -0.0435
# Iter: 4270, running avg loss: -0.0435
# Iter: 4280, running avg loss: -0.0434
# Iter: 4290, running avg loss: -0.0435
# Iter: 4300, running avg loss: -0.0431
# Iter: 4310, running avg loss: -0.0434
# Iter: 4320, running avg loss: -0.0436
# Iter: 4330, running avg loss: -0.0438
# Iter: 4340, running avg loss: -0.0442
# Iter: 4350, running avg loss: -0.0437
# Iter: 4360, running avg loss: -0.0439
# Iter: 4370, running avg loss: -0.0438
# Iter: 4380, running avg loss: -0.0441
# Iter: 4390, running avg loss: -0.0438
# Iter: 4400, running avg loss: -0.0439
# Iter: 4410, running avg loss: -0.0443
# Iter: 4420, running avg loss: -0.0445
# Iter: 4430, running avg loss: -0.0442
# Iter: 4440, running avg loss: -0.0443
# Iter: 4450, running avg loss: -0.0444
# Iter: 4460, running avg loss: -0.0437
# Iter: 4470, running avg loss: -0.0438
# Iter: 4480, running avg loss: -0.0440
# Iter: 4490, running avg loss: -0.0441
# Iter: 4500, running avg loss: -0.0438
# Iter: 4510, running avg loss: -0.0442
# Iter: 4520, running avg loss: -0.0444
# Iter: 4530, running avg loss: -0.0442
# Iter: 4540, running avg loss: -0.0441
# Iter: 4550, running avg loss: -0.0444
# Iter: 4560, running avg loss: -0.0443
# Iter: 4570, running avg loss: -0.0446
# Iter: 4580, running avg loss: -0.0443
# Iter: 4590, running avg loss: -0.0440
# Iter: 4600, running avg loss: -0.0443
# Iter: 4610, running avg loss: -0.0443
# Iter: 4620, running avg loss: -0.0440
# Iter: 4630, running avg loss: -0.0441
# Iter: 4640, running avg loss: -0.0443
# Iter: 4650, running avg loss: -0.0442
# Iter: 4660, running avg loss: -0.0441
# Iter: 4670, running avg loss: -0.0438
# Iter: 4680, running avg loss: -0.0435
# Iter: 4690, running avg loss: -0.0435
# Iter: 4700, running avg loss: -0.0440
# Iter: 4710, running avg loss: -0.0436
# Iter: 4720, running avg loss: -0.0439
# Iter: 4730, running avg loss: -0.0438
# Iter: 4740, running avg loss: -0.0441
# Iter: 4750, running avg loss: -0.0441
# Iter: 4760, running avg loss: -0.0445
# Iter: 4770, running avg loss: -0.0443
# Iter: 4780, running avg loss: -0.0443
# Iter: 4790, running avg loss: -0.0441
# Iter: 4800, running avg loss: -0.0439
# Iter: 4810, running avg loss: -0.0439
# Iter: 4820, running avg loss: -0.0443
# Iter: 4830, running avg loss: -0.0444
# Iter: 4840, running avg loss: -0.0446
# Iter: 4850, running avg loss: -0.0443
# Iter: 4860, running avg loss: -0.0444
# Iter: 4870, running avg loss: -0.0444
# Iter: 4880, running avg loss: -0.0446
# Iter: 4890, running avg loss: -0.0442
# Iter: 4900, running avg loss: -0.0439
# Iter: 4910, running avg loss: -0.0438
# Iter: 4920, running avg loss: -0.0437
# Iter: 4930, running avg loss: -0.0434
# Iter: 4940, running avg loss: -0.0431
# Iter: 4950, running avg loss: -0.0430
# Iter: 4960, running avg loss: -0.0428
# Iter: 4970, running avg loss: -0.0430
# Iter: 4980, running avg loss: -0.0433
# Iter: 4990, running avg loss: -0.0429
# Iter: 5000, running avg loss: -0.0428
# Iter: 5010, running avg loss: -0.0427
# Iter: 5020, running avg loss: -0.0425
# Iter: 5030, running avg loss: -0.0424
# Iter: 5040, running avg loss: -0.0429
# Iter: 5050, running avg loss: -0.0428
# Iter: 5060, running avg loss: -0.0429
# Iter: 5070, running avg loss: -0.0430
# Iter: 5080, running avg loss: -0.0432
# Iter: 5090, running avg loss: -0.0429
# Iter: 5100, running avg loss: -0.0434
# Iter: 5110, running avg loss: -0.0439
# Iter: 5120, running avg loss: -0.0438
# Iter: 5130, running avg loss: -0.0443
# Iter: 5140, running avg loss: -0.0437
# Iter: 5150, running avg loss: -0.0433
# Iter: 5160, running avg loss: -0.0432
# Iter: 5170, running avg loss: -0.0433
# Iter: 5180, running avg loss: -0.0435
# Iter: 5190, running avg loss: -0.0440
# Iter: 5200, running avg loss: -0.0437
# Iter: 5210, running avg loss: -0.0434
# Iter: 5220, running avg loss: -0.0435
# Iter: 5230, running avg loss: -0.0432
# Iter: 5240, running avg loss: -0.0432
# Iter: 5250, running avg loss: -0.0433
# Iter: 5260, running avg loss: -0.0436
# Iter: 5270, running avg loss: -0.0437
# Iter: 5280, running avg loss: -0.0437
# Iter: 5290, running avg loss: -0.0439
# Iter: 5300, running avg loss: -0.0443
# Iter: 5310, running avg loss: -0.0439
# Iter: 5320, running avg loss: -0.0438
# Iter: 5330, running avg loss: -0.0433
# Iter: 5340, running avg loss: -0.0434
# Iter: 5350, running avg loss: -0.0435
# Iter: 5360, running avg loss: -0.0434
# Iter: 5370, running avg loss: -0.0437
# Iter: 5380, running avg loss: -0.0432
# Iter: 5390, running avg loss: -0.0433
# Iter: 5400, running avg loss: -0.0437
# Iter: 5410, running avg loss: -0.0439
# Iter: 5420, running avg loss: -0.0443
# Iter: 5430, running avg loss: -0.0442
# Iter: 5440, running avg loss: -0.0445
# Iter: 5450, running avg loss: -0.0444
# Iter: 5460, running avg loss: -0.0445
# Iter: 5470, running avg loss: -0.0442
# Iter: 5480, running avg loss: -0.0439
# Iter: 5490, running avg loss: -0.0436
# Iter: 5500, running avg loss: -0.0437
# Iter: 5510, running avg loss: -0.0442
# Iter: 5520, running avg loss: -0.0439
# Iter: 5530, running avg loss: -0.0439
# Iter: 5540, running avg loss: -0.0436
# Iter: 5550, running avg loss: -0.0431
# Iter: 5560, running avg loss: -0.0436
# Iter: 5570, running avg loss: -0.0440
# Iter: 5580, running avg loss: -0.0442
# Iter: 5590, running avg loss: -0.0445
# Iter: 5600, running avg loss: -0.0445
# Iter: 5610, running avg loss: -0.0447
# Iter: 5620, running avg loss: -0.0450
# Iter: 5630, running avg loss: -0.0447
# Iter: 5640, running avg loss: -0.0446
# Iter: 5650, running avg loss: -0.0445
# Iter: 5660, running avg loss: -0.0442
# Iter: 5670, running avg loss: -0.0442
# Iter: 5680, running avg loss: -0.0443
# Iter: 5690, running avg loss: -0.0443
# Iter: 5700, running avg loss: -0.0445
# Iter: 5710, running avg loss: -0.0447
# Iter: 5720, running avg loss: -0.0446
# Iter: 5730, running avg loss: -0.0445
# Iter: 5740, running avg loss: -0.0444
# Iter: 5750, running avg loss: -0.0447
# Iter: 5760, running avg loss: -0.0443
# Iter: 5770, running avg loss: -0.0442
# Iter: 5780, running avg loss: -0.0442
# Iter: 5790, running avg loss: -0.0440
# Iter: 5800, running avg loss: -0.0443
# Iter: 5810, running avg loss: -0.0440
# Iter: 5820, running avg loss: -0.0439
# Iter: 5830, running avg loss: -0.0429
# Iter: 5840, running avg loss: -0.0430
# Iter: 5850, running avg loss: -0.0427
# Iter: 5860, running avg loss: -0.0428
# Iter: 5870, running avg loss: -0.0432
# Iter: 5880, running avg loss: -0.0431
# Iter: 5890, running avg loss: -0.0432
# Iter: 5900, running avg loss: -0.0433
# Iter: 5910, running avg loss: -0.0434
# Iter: 5920, running avg loss: -0.0433
# Iter: 5930, running avg loss: -0.0434
# Iter: 5940, running avg loss: -0.0438
# Iter: 5950, running avg loss: -0.0433
# Iter: 5960, running avg loss: -0.0430
# Iter: 5970, running avg loss: -0.0432
# Iter: 5980, running avg loss: -0.0433
# Iter: 5990, running avg loss: -0.0431
# Iter: 6000, running avg loss: -0.0435
# Iter: 6010, running avg loss: -0.0432
# Iter: 6020, running avg loss: -0.0436
# Iter: 6030, running avg loss: -0.0438
# Iter: 6040, running avg loss: -0.0435
# Iter: 6050, running avg loss: -0.0438
# Iter: 6060, running avg loss: -0.0442
# Iter: 6070, running avg loss: -0.0440
# Iter: 6080, running avg loss: -0.0440
# Iter: 6090, running avg loss: -0.0442
# Iter: 6100, running avg loss: -0.0445
# Iter: 6110, running avg loss: -0.0446
# Iter: 6120, running avg loss: -0.0448
# Iter: 6130, running avg loss: -0.0445
# Iter: 6140, running avg loss: -0.0445
# Iter: 6150, running avg loss: -0.0442
# Iter: 6160, running avg loss: -0.0442
# Iter: 6170, running avg loss: -0.0442
# Iter: 6180, running avg loss: -0.0446
# Iter: 6190, running avg loss: -0.0447
# Iter: 6200, running avg loss: -0.0444
# Iter: 6210, running avg loss: -0.0442
# Iter: 6220, running avg loss: -0.0441
# Iter: 6230, running avg loss: -0.0441
# Iter: 6240, running avg loss: -0.0443
# Iter: 6250, running avg loss: -0.0443
# Iter: 6260, running avg loss: -0.0441
# Iter: 6270, running avg loss: -0.0440
# Iter: 6280, running avg loss: -0.0436
# Iter: 6290, running avg loss: -0.0444
# Iter: 6300, running avg loss: -0.0447
# Iter: 6310, running avg loss: -0.0445
# Iter: 6320, running avg loss: -0.0448
# Iter: 6330, running avg loss: -0.0451
# Iter: 6340, running avg loss: -0.0451
# Iter: 6350, running avg loss: -0.0447
# Iter: 6360, running avg loss: -0.0447
# Iter: 6370, running avg loss: -0.0443
# Iter: 6380, running avg loss: -0.0440
# Iter: 6390, running avg loss: -0.0436
# Iter: 6400, running avg loss: -0.0435
# Iter: 6410, running avg loss: -0.0433
# Iter: 6420, running avg loss: -0.0426
# Iter: 6430, running avg loss: -0.0423
# Iter: 6440, running avg loss: -0.0422
# Iter: 6450, running avg loss: -0.0427
# Iter: 6460, running avg loss: -0.0430
# Iter: 6470, running avg loss: -0.0428
# Iter: 6480, running avg loss: -0.0429
# Iter: 6490, running avg loss: -0.0430
# Iter: 6500, running avg loss: -0.0433
# Iter: 6510, running avg loss: -0.0435
# Iter: 6520, running avg loss: -0.0434
# Iter: 6530, running avg loss: -0.0438
# Iter: 6540, running avg loss: -0.0437
# Iter: 6550, running avg loss: -0.0437
# Iter: 6560, running avg loss: -0.0440
# Iter: 6570, running avg loss: -0.0436
# Iter: 6580, running avg loss: -0.0433
# Iter: 6590, running avg loss: -0.0434
# Iter: 6600, running avg loss: -0.0436
# Iter: 6610, running avg loss: -0.0437
# Iter: 6620, running avg loss: -0.0433
# Iter: 6630, running avg loss: -0.0434
# Iter: 6640, running avg loss: -0.0434
# Iter: 6650, running avg loss: -0.0438
# Iter: 6660, running avg loss: -0.0436
# Iter: 6670, running avg loss: -0.0427
# Iter: 6680, running avg loss: -0.0428
# Iter: 6690, running avg loss: -0.0423
# Iter: 6700, running avg loss: -0.0422
# Iter: 6710, running avg loss: -0.0421
# Iter: 6720, running avg loss: -0.0418
# Iter: 6730, running avg loss: -0.0423
# Iter: 6740, running avg loss: -0.0430
# Iter: 6750, running avg loss: -0.0435
# Iter: 6760, running avg loss: -0.0436
# Iter: 6770, running avg loss: -0.0436
# Iter: 6780, running avg loss: -0.0438
# Iter: 6790, running avg loss: -0.0438
# Iter: 6800, running avg loss: -0.0434
# Iter: 6810, running avg loss: -0.0429
# Iter: 6820, running avg loss: -0.0435
# Iter: 6830, running avg loss: -0.0438
# Iter: 6840, running avg loss: -0.0432
# Iter: 6850, running avg loss: -0.0434
# Iter: 6860, running avg loss: -0.0433
# Iter: 6870, running avg loss: -0.0430
# Iter: 6880, running avg loss: -0.0428
# Iter: 6890, running avg loss: -0.0421
# Iter: 6900, running avg loss: -0.0421
# Iter: 6910, running avg loss: -0.0421
# Iter: 6920, running avg loss: -0.0427
# Iter: 6930, running avg loss: -0.0429
# Iter: 6940, running avg loss: -0.0432
# Iter: 6950, running avg loss: -0.0429
# Iter: 6960, running avg loss: -0.0429
# Iter: 6970, running avg loss: -0.0427
# Iter: 6980, running avg loss: -0.0423
# Iter: 6990, running avg loss: -0.0425
# Iter: 7000, running avg loss: -0.0429
# Iter: 7010, running avg loss: -0.0430
# Iter: 7020, running avg loss: -0.0431
# Iter: 7030, running avg loss: -0.0430
# Iter: 7040, running avg loss: -0.0431
# Iter: 7050, running avg loss: -0.0434
# Iter: 7060, running avg loss: -0.0428
# Iter: 7070, running avg loss: -0.0429
# Iter: 7080, running avg loss: -0.0430
# Iter: 7090, running avg loss: -0.0426
# Iter: 7100, running avg loss: -0.0427
# Iter: 7110, running avg loss: -0.0427
# Iter: 7120, running avg loss: -0.0430
# Iter: 7130, running avg loss: -0.0432
# Iter: 7140, running avg loss: -0.0436
# Iter: 7150, running avg loss: -0.0438
# Iter: 7160, running avg loss: -0.0438
# Iter: 7170, running avg loss: -0.0439
# Iter: 7180, running avg loss: -0.0438
# Iter: 7190, running avg loss: -0.0438
# Iter: 7200, running avg loss: -0.0438
# Iter: 7210, running avg loss: -0.0436
# Iter: 7220, running avg loss: -0.0436
# Iter: 7230, running avg loss: -0.0433
# Iter: 7240, running avg loss: -0.0436
# Iter: 7250, running avg loss: -0.0437
# Iter: 7260, running avg loss: -0.0438
# Iter: 7270, running avg loss: -0.0441
# Iter: 7280, running avg loss: -0.0442
# Iter: 7290, running avg loss: -0.0442
# Iter: 7300, running avg loss: -0.0443
# Iter: 7310, running avg loss: -0.0436
# Iter: 7320, running avg loss: -0.0434
# Iter: 7330, running avg loss: -0.0437
# Iter: 7340, running avg loss: -0.0437
# Iter: 7350, running avg loss: -0.0441
# Iter: 7360, running avg loss: -0.0438
# Iter: 7370, running avg loss: -0.0436
# Iter: 7380, running avg loss: -0.0434
# Iter: 7390, running avg loss: -0.0436
# Iter: 7400, running avg loss: -0.0437
# Iter: 7410, running avg loss: -0.0431
# Iter: 7420, running avg loss: -0.0431
# Iter: 7430, running avg loss: -0.0433
# Iter: 7440, running avg loss: -0.0433
# Iter: 7450, running avg loss: -0.0435
# Iter: 7460, running avg loss: -0.0434
# Iter: 7470, running avg loss: -0.0435
# Iter: 7480, running avg loss: -0.0433
# Iter: 7490, running avg loss: -0.0436
# Iter: 7500, running avg loss: -0.0437
# Iter: 7510, running avg loss: -0.0441
# Iter: 7520, running avg loss: -0.0444
# Iter: 7530, running avg loss: -0.0448
# Iter: 7540, running avg loss: -0.0449
# Iter: 7550, running avg loss: -0.0448
# Iter: 7560, running avg loss: -0.0448
# Iter: 7570, running avg loss: -0.0446
# Iter: 7580, running avg loss: -0.0445
# Iter: 7590, running avg loss: -0.0444
# Iter: 7600, running avg loss: -0.0443
# Iter: 7610, running avg loss: -0.0444
# Iter: 7620, running avg loss: -0.0443
# Iter: 7630, running avg loss: -0.0445
# Iter: 7640, running avg loss: -0.0443
# Iter: 7650, running avg loss: -0.0443
# Iter: 7660, running avg loss: -0.0444
# Iter: 7670, running avg loss: -0.0445
# Iter: 7680, running avg loss: -0.0442
# Iter: 7690, running avg loss: -0.0441
# Iter: 7700, running avg loss: -0.0440
# Iter: 7710, running avg loss: -0.0442
# Iter: 7720, running avg loss: -0.0441
# Iter: 7730, running avg loss: -0.0439
# Iter: 7740, running avg loss: -0.0443
# Iter: 7750, running avg loss: -0.0444
# Iter: 7760, running avg loss: -0.0446
# Iter: 7770, running avg loss: -0.0442
# Iter: 7780, running avg loss: -0.0443
# Iter: 7790, running avg loss: -0.0444
# Iter: 7800, running avg loss: -0.0442
# Iter: 7810, running avg loss: -0.0442
# Iter: 7820, running avg loss: -0.0440
# Iter: 7830, running avg loss: -0.0441
# Iter: 7840, running avg loss: -0.0440
# Iter: 7850, running avg loss: -0.0440
# Iter: 7860, running avg loss: -0.0443
# Iter: 7870, running avg loss: -0.0444
# Iter: 7880, running avg loss: -0.0448
# Iter: 7890, running avg loss: -0.0446
# Iter: 7900, running avg loss: -0.0444
# Iter: 7910, running avg loss: -0.0447
# Iter: 7920, running avg loss: -0.0448
# Iter: 7930, running avg loss: -0.0451
# Iter: 7940, running avg loss: -0.0452
# Iter: 7950, running avg loss: -0.0454
# Iter: 7960, running avg loss: -0.0452
# Iter: 7970, running avg loss: -0.0451
# Iter: 7980, running avg loss: -0.0454
# Iter: 7990, running avg loss: -0.0453
# Iter: 8000, running avg loss: -0.0457
# Iter: 8010, running avg loss: -0.0453
# Iter: 8020, running avg loss: -0.0457
# Iter: 8030, running avg loss: -0.0462
# Iter: 8040, running avg loss: -0.0461
# Iter: 8050, running avg loss: -0.0455
# Iter: 8060, running avg loss: -0.0454
# Iter: 8070, running avg loss: -0.0456
# Iter: 8080, running avg loss: -0.0451
# Iter: 8090, running avg loss: -0.0447
# Iter: 8100, running avg loss: -0.0443
# Iter: 8110, running avg loss: -0.0446
# Iter: 8120, running avg loss: -0.0448
# Iter: 8130, running avg loss: -0.0446
# Iter: 8140, running avg loss: -0.0450
# Iter: 8150, running avg loss: -0.0451
# Iter: 8160, running avg loss: -0.0452
# Iter: 8170, running avg loss: -0.0456
# Iter: 8180, running avg loss: -0.0456
# Iter: 8190, running avg loss: -0.0456
# Iter: 8200, running avg loss: -0.0450
# Iter: 8210, running avg loss: -0.0448
# Iter: 8220, running avg loss: -0.0452
# Iter: 8230, running avg loss: -0.0455
# Iter: 8240, running avg loss: -0.0455
# Iter: 8250, running avg loss: -0.0456
# Iter: 8260, running avg loss: -0.0457
# Iter: 8270, running avg loss: -0.0459
# Iter: 8280, running avg loss: -0.0457
# Iter: 8290, running avg loss: -0.0454
# Iter: 8300, running avg loss: -0.0453
# Iter: 8310, running avg loss: -0.0450
# Iter: 8320, running avg loss: -0.0449
# Iter: 8330, running avg loss: -0.0448
# Iter: 8340, running avg loss: -0.0448
# Iter: 8350, running avg loss: -0.0452
# Iter: 8360, running avg loss: -0.0453
# Iter: 8370, running avg loss: -0.0457
# Iter: 8380, running avg loss: -0.0461
# Iter: 8390, running avg loss: -0.0453
# Iter: 8400, running avg loss: -0.0456
# Iter: 8410, running avg loss: -0.0452
# Iter: 8420, running avg loss: -0.0451
# Iter: 8430, running avg loss: -0.0454
# Iter: 8440, running avg loss: -0.0454
# Iter: 8450, running avg loss: -0.0449
# Iter: 8460, running avg loss: -0.0446
# Iter: 8470, running avg loss: -0.0449
# Iter: 8480, running avg loss: -0.0452
# Iter: 8490, running avg loss: -0.0452
# Iter: 8500, running avg loss: -0.0449
# Iter: 8510, running avg loss: -0.0452
# Iter: 8520, running avg loss: -0.0452
# Iter: 8530, running avg loss: -0.0449
# Iter: 8540, running avg loss: -0.0447
# Iter: 8550, running avg loss: -0.0448
# Iter: 8560, running avg loss: -0.0446
# Iter: 8570, running avg loss: -0.0445
# Iter: 8580, running avg loss: -0.0449
# Iter: 8590, running avg loss: -0.0455
# Iter: 8600, running avg loss: -0.0455
# Iter: 8610, running avg loss: -0.0452
# Iter: 8620, running avg loss: -0.0453
# Iter: 8630, running avg loss: -0.0452
# Iter: 8640, running avg loss: -0.0455
# Iter: 8650, running avg loss: -0.0459
# Iter: 8660, running avg loss: -0.0455
# Iter: 8670, running avg loss: -0.0453
# Iter: 8680, running avg loss: -0.0451
# Iter: 8690, running avg loss: -0.0450
# Iter: 8700, running avg loss: -0.0455
# Iter: 8710, running avg loss: -0.0455
# Iter: 8720, running avg loss: -0.0453
# Iter: 8730, running avg loss: -0.0453
# Iter: 8740, running avg loss: -0.0455
# Iter: 8750, running avg loss: -0.0449
# Iter: 8760, running avg loss: -0.0450
# Iter: 8770, running avg loss: -0.0452
# Iter: 8780, running avg loss: -0.0456
# Iter: 8790, running avg loss: -0.0454
# Iter: 8800, running avg loss: -0.0455
# Iter: 8810, running avg loss: -0.0450
# Iter: 8820, running avg loss: -0.0447
# Iter: 8830, running avg loss: -0.0447
# Iter: 8840, running avg loss: -0.0445
# Iter: 8850, running avg loss: -0.0445
# Iter: 8860, running avg loss: -0.0445
# Iter: 8870, running avg loss: -0.0444
# Iter: 8880, running avg loss: -0.0446
# Iter: 8890, running avg loss: -0.0446
# Iter: 8900, running avg loss: -0.0442
# Iter: 8910, running avg loss: -0.0438
# Iter: 8920, running avg loss: -0.0437
# Iter: 8930, running avg loss: -0.0434
# Iter: 8940, running avg loss: -0.0435
# Iter: 8950, running avg loss: -0.0436
# Iter: 8960, running avg loss: -0.0436
# Iter: 8970, running avg loss: -0.0441
# Iter: 8980, running avg loss: -0.0441
# Iter: 8990, running avg loss: -0.0440
# Iter: 9000, running avg loss: -0.0446
# Iter: 9010, running avg loss: -0.0445
# Iter: 9020, running avg loss: -0.0444
# Iter: 9030, running avg loss: -0.0447
# Iter: 9040, running avg loss: -0.0445
# Iter: 9050, running avg loss: -0.0444
# Iter: 9060, running avg loss: -0.0445
# Iter: 9070, running avg loss: -0.0442
# Iter: 9080, running avg loss: -0.0442
# Iter: 9090, running avg loss: -0.0441
# Iter: 9100, running avg loss: -0.0439
# Iter: 9110, running avg loss: -0.0442
# Iter: 9120, running avg loss: -0.0442
# Iter: 9130, running avg loss: -0.0448
# Iter: 9140, running avg loss: -0.0450
# Iter: 9150, running avg loss: -0.0451
# Iter: 9160, running avg loss: -0.0457
# Iter: 9170, running avg loss: -0.0457
# Iter: 9180, running avg loss: -0.0454
# Iter: 9190, running avg loss: -0.0452
# Iter: 9200, running avg loss: -0.0452
# Iter: 9210, running avg loss: -0.0457
# Iter: 9220, running avg loss: -0.0457
# Iter: 9230, running avg loss: -0.0460
# Iter: 9240, running avg loss: -0.0457
# Iter: 9250, running avg loss: -0.0455
# Iter: 9260, running avg loss: -0.0455
# Iter: 9270, running avg loss: -0.0454
# Iter: 9280, running avg loss: -0.0455
# Iter: 9290, running avg loss: -0.0454
# Iter: 9300, running avg loss: -0.0454
# Iter: 9310, running avg loss: -0.0457
# Iter: 9320, running avg loss: -0.0454
# Iter: 9330, running avg loss: -0.0454
# Iter: 9340, running avg loss: -0.0453
# Iter: 9350, running avg loss: -0.0449
# Iter: 9360, running avg loss: -0.0450
# Iter: 9370, running avg loss: -0.0450
# Iter: 9380, running avg loss: -0.0449
# Iter: 9390, running avg loss: -0.0452
# Iter: 9400, running avg loss: -0.0453
# Iter: 9410, running avg loss: -0.0456
# Iter: 9420, running avg loss: -0.0454
# Iter: 9430, running avg loss: -0.0456
# Iter: 9440, running avg loss: -0.0454
# Iter: 9450, running avg loss: -0.0449
# Iter: 9460, running avg loss: -0.0451
# Iter: 9470, running avg loss: -0.0455
# Iter: 9480, running avg loss: -0.0456
# Iter: 9490, running avg loss: -0.0458
# Iter: 9500, running avg loss: -0.0457
# Iter: 9510, running avg loss: -0.0456
# Iter: 9520, running avg loss: -0.0455
# Iter: 9530, running avg loss: -0.0458
# Iter: 9540, running avg loss: -0.0459
# Iter: 9550, running avg loss: -0.0459
# Iter: 9560, running avg loss: -0.0455
# Iter: 9570, running avg loss: -0.0452
# Iter: 9580, running avg loss: -0.0450
# Iter: 9590, running avg loss: -0.0449
# Iter: 9600, running avg loss: -0.0451
# Iter: 9610, running avg loss: -0.0456
# Iter: 9620, running avg loss: -0.0457
# Iter: 9630, running avg loss: -0.0456
# Iter: 9640, running avg loss: -0.0457
# Iter: 9650, running avg loss: -0.0458
# Iter: 9660, running avg loss: -0.0454
# Iter: 9670, running avg loss: -0.0451
# Iter: 9680, running avg loss: -0.0451
# Iter: 9690, running avg loss: -0.0451
# Iter: 9700, running avg loss: -0.0451
# Iter: 9710, running avg loss: -0.0450
# Iter: 9720, running avg loss: -0.0453
# Iter: 9730, running avg loss: -0.0450
# Iter: 9740, running avg loss: -0.0446
# Iter: 9750, running avg loss: -0.0443
# Iter: 9760, running avg loss: -0.0443
# Iter: 9770, running avg loss: -0.0436
# Iter: 9780, running avg loss: -0.0432
# Iter: 9790, running avg loss: -0.0433
# Iter: 9800, running avg loss: -0.0434
# Iter: 9810, running avg loss: -0.0440
# Iter: 9820, running avg loss: -0.0440
# Iter: 9830, running avg loss: -0.0444
# Iter: 9840, running avg loss: -0.0445
# Iter: 9850, running avg loss: -0.0442
# Iter: 9860, running avg loss: -0.0446
# Iter: 9870, running avg loss: -0.0445
# Iter: 9880, running avg loss: -0.0449
# Iter: 9890, running avg loss: -0.0447
# Iter: 9900, running avg loss: -0.0452
# Iter: 9910, running avg loss: -0.0453
# Iter: 9920, running avg loss: -0.0450
# Iter: 9930, running avg loss: -0.0453
# Iter: 9940, running avg loss: -0.0453
# Iter: 9950, running avg loss: -0.0453
# Iter: 9960, running avg loss: -0.0452
# Iter: 9970, running avg loss: -0.0451
# Iter: 9980, running avg loss: -0.0451
# Iter: 9990, running avg loss: -0.0449
# Iter: 10000, running avg loss: -0.0453

# %%
loss_meter.plot_history()

# %%
# Get points from the original distribution
y_0 = torch.distributions.normal.Normal(torch.tensor([0.0]), torch.tensor([1.0])).sample(sample_shape=torch.Size([100000])).type(torch.float32)
# Get their log probability
logp_t0 = torch.distributions.normal.Normal(torch.tensor([0.0]), torch.tensor([1.0])).log_prob(y_0).type(torch.float32)

# Transform the points
y_t_empirical, _ = odeint(
        func, 
        (y_0, logp_t0), 
        torch.tensor([t0, t1]).type(torch.float32), 
        method='dopri5', 
        atol=1e-5, 
        rtol=1e-5)

# Plot the objective distribution
x = np.linspace(0, 1, 1000)
obj = 0.5 * beta.pdf(x, 2, 5) + 0.5 * beta.pdf(x, 5, 2)

# Plot the learnt distribution
x_tensor = torch.tensor(np.linspace(-20,20,1000)).type(torch.float32)
origin_d = torch.distributions.normal.Normal(torch.tensor([0.0]), torch.tensor([1.0])).log_prob(x_tensor).type(torch.float32)

x_t, logp_x_t = odeint(
        func, 
        (x_tensor.view(-1,1), origin_d.view(-1,1)), 
        torch.tensor([t0, t1]).type(torch.float32), 
        method='dopri5', 
        atol=1e-5, 
        rtol=1e-5
    )
x_t, logp_x_t = x_t[-1].detach().cpu().numpy(), logp_x_t[-1].exp().detach().cpu().numpy()


#plt.hist(, bins=100, density=True, label='Original histogram')
plt.plot(x, obj, label='Objective distribution')
plt.hist(y_t_empirical[-1].detach().cpu().numpy(), bins=100, density=True, label='Learnt histogram')
plt.plot(x_t, logp_x_t, '-.', label='Learnt distribution')
plt.title('Transformed distribution')
plt.xlim(0,1)
plt.legend()
plt.show()

# %%
x_0 = torch.distributions.normal.Normal(torch.tensor([0.0]), torch.tensor([1.0])).sample(sample_shape=torch.Size([100000])).type(torch.float32)

logp_t0 = torch.distributions.normal.Normal(torch.tensor([0.0]), torch.tensor([1.0])).log_prob(y_0).type(torch.float32)

times = np.linspace(t0, t1, 10)

x_t, _ = odeint(
        func, 
        (x_0, logp_t0), 
        torch.tensor(times).type(torch.float32), 
        method='dopri5', 
        atol=1e-5, 
        rtol=1e-5
    )

x_t = x_t.detach().cpu().numpy()

if not os.path.exists('cnf_one_images_2'):
    os.makedirs('cnf_one_images_2')

# Define the function to generate the plot
def plot_and_save(i):
    fig, ax = plt.subplots(1, 1, figsize=(5, 5))
    plt.suptitle('Transformed distribution at time t={:.2f}'.format(times[i]))
    plt.tight_layout()
    
    
    ax.plot(x, obj, label='Objective distribution')
    ax.hist(x_t[i], bins=100, density=True)
    plt.xlim(-5,5)
    plt.ylim(0,1.3)

    # Save the plot as an image
    plt.savefig(os.path.join('cnf_one_images_2','frame{}.png'.format(i)))
    plt.close()


# Generate the GIF
for i in range(10):
    plot_and_save(i)

# Create the GIF using imageio
gif_images = [os.path.join('cnf_one_images_2','frame{}.png'.format(i)) for i in range(10)]

img, *imgs = [Image.open(img) for img in gif_images]
gif_path = os.path.join('cnf_one_images_2','result.gif')
img.save(fp=gif_path, format='GIF', append_images=imgs,
         save_all=True, duration=500, loop=0)
display(HTML(f'<img src="{gif_path}">'))
img.close()
for im in imgs:
    im.close()
# Out:
# <img src="cnf_one_images_2/result.gif">
